# %% [markdown]
# <a href="https://colab.research.google.com/github/dddoriath/Probability/blob/main/%5BExercises_2%263%5DPandas_Handling_Nulls_and_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Operating on Null Values

# %%
data = pd.Series([3.1414, np.nan, 'hello world', None])
data
# Out:
# 0         3.1414
# 1            NaN
# 2    hello world
# 3           None
# dtype: object

# %% [markdown]
# #### Create a boolean mask for rows containing a non-null value

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# #### Create a table containing all non-null values from data using a masking operation

# %%
data.dropna()
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %%
data[data.notnull()]
# Out:
# 0         3.1414
# 2    hello world
# dtype: object

# %% [markdown]
# ### Dropping null values

# %%
df = pd.DataFrame([[1,      np.nan, 2     ],
                   [2,      3,      5     ],
                   [np.nan, 4,      6     ],
                   [np.nan, np.nan, np.nan],
                   [6     , np.nan, np.nan]])
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table with all non-null values from data using the dropna method

# %%
df.dropna()
# Out:
#      0    1    2
# 1  2.0  3.0  5.0

# %% [markdown]
# #### Create a table will all non-null rows from df

# %%
df.dropna(axis = 'rows')
# Out:
#      0    1    2
# 1  2.0  3.0  5.0

# %% [markdown]
# #### Create a table will all columns with less than three non-null values from df

# %%
df.dropna(axis = 'columns', thresh=3)
# Out:
#      0    2
# 0  1.0  2.0
# 1  2.0  5.0
# 2  NaN  6.0
# 3  NaN  NaN
# 4  6.0  NaN

# %% [markdown]
# ### Filling null values

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled with 1

# %%
data.fillna(1)
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    1.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the forward-fill method

# %%
data.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %% [markdown]
# #### Create a table with all null values of data filled using the back-fill method

# %%
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %% [markdown]
# For ``DataFrame``s, the options are similar, but we can also specify an ``axis`` along which the fills take place:

# %%
df
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0
# 3  NaN  NaN  NaN
# 4  6.0  NaN  NaN

# %% [markdown]
# #### Create a table will all null values of df filled using  the forward-fill method down each column

# %%
df.fillna(method= 'ffill', axis = 'rows')
# Out:
#      0    1    2
# 0  1.0  NaN  2.0
# 1  2.0  3.0  5.0
# 2  2.0  4.0  6.0
# 3  2.0  4.0  6.0
# 4  6.0  4.0  6.0

# %% [markdown]
# # Connect to the Strata Scratch Datasets To Explore Our Datasets

# %% [markdown]
# This notebook will guide you through the process of connecting to the Strata Scratch database to query datasets. Simply download this notebook and follow the steps.

# %% [markdown]
# ## Connect to Strata Scratch
#
# Remember to input your username and password

# %% [markdown]
# ## Pull Data From Strata Scratch

# %%
db_data = pd.read_csv('NFL.csv')

# %%
db_data.head()
# Out:
#              Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 0      John Abraham  OLB  76  252   4.55       NaN        NaN        NaN
# 1   Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN
# 2    Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0
# 3      Kyle Allamon   TE  74  253   4.97      29.0        NaN      104.0
# 4  Rashard Anderson   CB  74  206   4.55      34.0        NaN      123.0
#
#    Cone  Shuttle  Year    Pfr_ID    AV                Team  Round   Pick
# 0   NaN      NaN  2000  AbraJo00  26.0       New York Jets    1.0   13.0
# 1   NaN      NaN  2000  AlexSh00  26.0    Seattle Seahawks    1.0   19.0
# 2  8.48     4.98  2000  AlfoDa20   0.0  Kansas City Chiefs    6.0  188.0
# 3  7.29     4.49  2000       NaN   0.0                 NaN    NaN    NaN
# 4  7.18     4.15  2000  AndeRa21   6.0   Carolina Panthers    1.0   23.0

# %% [markdown]
# # Basic Pandas Functionality

# %% [markdown]
# #### Print the information about db_data

# %%
db_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6218 entries, 0 to 6217
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Player     6218 non-null   object
#  1   Pos        6218 non-null   object
#  2   Ht         6218 non-null   int64
#  3   Wt         6218 non-null   int64
#  4   Forty      6046 non-null   float64
#  5   Vertical   4796 non-null   float64
#  6   BenchReps  4212 non-null   float64
#  7   BroadJump  4754 non-null   float64
#  8   Cone       3993 non-null   float64
#  9   Shuttle    4063 non-null   float64
#  10  Year       6218 non-null   int64
#  11  Pfr_ID     4895 non-null   object
#  12  AV         6218 non-null   float64
#  13  Team       3738 non-null   object
#  14  Round      3738 non-null   float64
#  15  Pick       3738 non-null   float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 777.4+ KB

# %% [markdown]
# #### Print the first 8 rows of db_data

# %%
db_data.head(3)
# Out:
#             Player  Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  Cone  \
# 0     John Abraham  OLB  76  252   4.55       NaN        NaN        NaN   NaN
# 1  Shaun Alexander   RB  72  218   4.58       NaN        NaN        NaN   NaN
# 2   Darnell Alford   OT  76  334   5.56      25.0       23.0       94.0  8.48
#
#    Shuttle  Year    Pfr_ID    AV                Team  Round   Pick
# 0      NaN  2000  AbraJo00  26.0       New York Jets    1.0   13.0
# 1      NaN  2000  AlexSh00  26.0    Seattle Seahawks    1.0   19.0
# 2     4.98  2000  AlfoDa20   0.0  Kansas City Chiefs    6.0  188.0

# %% [markdown]
# #### Print the last 10 rows of db_data

# %%
db_data.tail(10)
# Out:
#                Player   Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 6208      Jeff Wilson    RB  71  210    NaN       NaN       15.0        NaN
# 6209       Javon Wims    WR  75  215   4.53      33.5        NaN      113.0
# 6210  Anthony Winbush  EDGE  73  249    NaN       NaN       25.0      110.0
# 6211     Ryan Winslow     P  77  217    NaN       NaN        NaN        NaN
# 6212   Logan Woodside    QB  73  213   4.79      31.5        NaN      103.0
# 6213     Chris Worley   ILB  74  238   4.86      29.5       15.0        NaN
# 6214      Isaiah Wynn     G  75  313    NaN       NaN        NaN        NaN
# 6215     Isaac Yiadom    CB  73  190   4.52       NaN        8.0      120.0
# 6216      Kenny Young   ILB  73  236   4.60      36.0       23.0      117.0
# 6217     Trevon Young  EDGE  76  258   4.78      33.0       25.0      114.0
#
#       Cone  Shuttle  Year    Pfr_ID   AV Team  Round  Pick
# 6208   NaN      NaN  2018       NaN  0.0  NaN    NaN   NaN
# 6209  7.00      NaN  2018  WimsJa00  0.0  NaN    NaN   NaN
# 6210   NaN      NaN  2018       NaN  0.0  NaN    NaN   NaN
# 6211   NaN      NaN  2018       NaN  0.0  NaN    NaN   NaN
# 6212  6.94     4.15  2018  WoodLo00  0.0  NaN    NaN   NaN
# 6213   NaN      NaN  2018  WorlCh00  0.0  NaN    NaN   NaN
# 6214   NaN      NaN  2018  WynnIs00  0.0  NaN    NaN   NaN
# 6215   NaN     4.18  2018  YiadIs00  0.0  NaN    NaN   NaN
# 6216  7.38     4.48  2018       NaN  0.0  NaN    NaN   NaN
# 6217  6.99     4.40  2018  YounTr00  0.0  NaN    NaN   NaN

# %% [markdown]
# #### Print the summary statistics of db_data

# %%
db_data.describe().T
# Out:
#             count         mean        std      min      25%      50%      75%  \
# Ht         6218.0    73.798971   2.621373    65.00    72.00    74.00    76.00
# Wt         6218.0   243.372145  45.103814   149.00   206.00   233.00   281.00
# Forty      6046.0     4.783784   0.305984     4.22     4.54     4.70     4.98
# Vertical   4796.0    32.818599   4.213729    17.50    30.00    33.00    35.50
# BenchReps  4212.0    20.926163   6.393679     2.00    16.00    21.00    25.00
# BroadJump  4754.0   113.943837   9.317031    74.00   108.00   115.00   121.00
# Cone       3993.0     7.282307   0.422882     6.28     6.97     7.19     7.54
# Shuttle    4063.0     4.390603   0.268836     3.73     4.19     4.35     4.56
# Year       6218.0  2009.041975   5.471056  2000.00  2004.00  2009.00  2014.00
# AV         6218.0     5.085719   7.546556    -4.00     0.00     1.00     8.00
# Round      3738.0     3.838684   1.952728     1.00     2.00     4.00     5.00
# Pick       3738.0   113.728464  70.605155     1.00    53.00   108.00   169.00
#
#                max
# Ht           82.00
# Wt          375.00
# Forty         6.05
# Vertical     46.00
# BenchReps    49.00
# BroadJump   147.00
# Cone          9.12
# Shuttle       5.56
# Year       2018.00
# AV           51.00
# Round         7.00
# Pick        260.00

# %% [markdown]
# ### Filtering Dataframes
#
# Remember: the syntax for filtering DataFrames is similar to that used for boolean masking

# %%
#import titanic
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Filter the data for females
#
# Remember: the head method can be used to make results more concise

# %%
data[data.sex == 'female'].head(2)
# Out:
#    passengerid  survived  pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 name     sex   age  sibsp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    parch            ticket     fare cabin embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# #### Filter for names and age of passengers with fares greater than 50

# %%
data.loc[data.fare > 50, ['name','age']]
# Out:
#                                                   name   age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 27                      Fortune, Mr. Charles Alexander  19.0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)   NaN
# ..                                                 ...   ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0
# 863                  Sage, Miss. Dorothy Edith "Dolly"   NaN
# 867               Roebling, Mr. Washington Augustus II  31.0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
#
# [160 rows x 2 columns]

# %% [markdown]
# ### Adding methods to filters

# %% [markdown]
# #### Print the number of second class passengers

# %%
data.pclass[data.pclass == 2].count()
# Out:
# 184

# %% [markdown]
# #### Print the survival rate of males in the third passenger class
#
# survival rate = mean of survived column

# %%
data.survived[(data.sex == 'male') & (data.pclass == 3)].mean()
# Out:
# 0.13544668587896252

# %%
data.groupby(['sex', 'pclass'])['survived'].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %% [markdown]
# #### Print the survival rate for women and children

# %%
data.survived[(data.sex == 'female')|(data.age<12)].mean()
# Out:
# 0.7228571428571429

# %% [markdown]
# #### Print the survival rate of men. Then, print the survival rate of women.
#
# This type of of group based aggregation will become simpler in the next section

# %%
data.groupby(['sex','pclass'])['survived','fare'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                survived        fare
# sex    pclass
# female 1       0.968085  106.125798
#        2       0.921053   21.970121
#        3       0.500000   16.118810
# male   1       0.368852   67.226127
#        2       0.157407   19.741782
#        3       0.135447   12.661633
